# %% [markdown]
# # 03 — Pandas 🐼
#
# Ce notebook reprend le [chapitre Pandas](https://matbog.gitbook.io/python/pandas) du site Learn Python.
#
# Chapitres associés :
#
# - [Lire des fichiers xlsx, csv, pkl](https://matbog.gitbook.io/python/pandas/lire-des-fichiers-xlsx-csv-pkl)
# - [Visualiser les données d'un DataFrame](https://matbog.gitbook.io/python/pandas/visualiser-les-donnees-dun-dataframe)
# - [Filtrer des données](https://matbog.gitbook.io/python/pandas/filtrer-des-donnees)
# - [Données temporelles et index](https://matbog.gitbook.io/python/pandas/donnees-temporelles-et-index)
# - [Catégoriser des données](https://matbog.gitbook.io/python/pandas/categoriser-des-donnees)
# - [Regroupements et sous-groupes](https://matbog.gitbook.io/python/pandas/regroupements-et-sous-groupes)
# - [Valeurs manquantes](https://matbog.gitbook.io/python/pandas/valeurs-manquantes)
# - [Joindre des DataFrames](https://matbog.gitbook.io/python/pandas/joindre-des-dataframes)
# - [Reshape et pivot](https://matbog.gitbook.io/python/pandas/reshape-et-pivot)
# - [Divers](https://matbog.gitbook.io/python/pandas/divers)
# - [Performances](https://matbog.gitbook.io/python/pandas/performances)
#
#
# <div style="border-left: 5px solid #20c997; background-color: #d1f7ec; padding: 10px; border-radius: 5px;">
# <b>💡 Rappel :</b><br>
#     <ul>
#         <li>Exécute les cellules avec <b>Shift + Enter</b></li>
#         <li>Écris ton code dans les cellules marquées <b># À compléter</b></li>
#         <li>Tu peux modifier les cellules autant de fois que nécessaire</li>
#         <li>Certaines cellules contiennent une <b>vérification simple</b></li>
#     </ul>
# </div>

# %% [markdown]
# ## 0. Échauffement

# %%
import pandas as pd
import numpy as np

print("Pandas et nUmPy sont prêts 🚀")

# %% [markdown]
# ## 0 bis. Jeu de données utilisé
#
# Pour garder le notebook compatible avec JupyterLite, on crée un petit jeu de données en mémoire.
#
# Chaque ligne représente un **mois** pour une **ville**.

# %%
df = pd.DataFrame({
    "ville": [
        "Paris", "Paris", "Paris", "Paris",
        "Lyon", "Lyon", "Lyon", "Lyon",
        "Marseille", "Marseille", "Marseille", "Marseille"
    ],
    "mois": [
        "2024-01", "2024-02", "2024-03", "2024-04",
        "2024-01", "2024-02", "2024-03", "2024-04",
        "2024-01", "2024-02", "2024-03", "2024-04"
    ],
    "tavg": [6.1, 7.8, 10.9, 13.2, 4.8, 6.9, 10.7, 13.8, 8.5, 9.6, 12.8, 15.4],
    "precip_mm": [54, 48, 46, 52, 42, 38, np.nan, 57, 61, 45, 39, 44],
    "wind_kmh": [18, 17, 16, 15, 14, 13, 12, 12, 21, 19, 18, 17],
    "humidite": [82, 79, 75, 72, 84, 79, 73, 69, 76, 73, 70, 67],
    "station": ["PAR", "PAR", "PAR", "PAR", "LYO", "LYO", "LYO", "LYO", "MRS", "MRS", "MRS", "MRS"],
    "zone_climatique": ["nord", "nord", "nord", "nord", "interieur", "interieur", "interieur", "interieur", "sud", "sud", "sud", "sud"]
})

df

# %% [markdown]
# ## 1. Lire des fichiers
#
# ### Exercice 1
# Écris les trois instructions Pandas qui permettent de lire :
# - un fichier CSV
# - un fichier Excel
#
# Tu peux utiliser des noms de fichiers fictifs liés à la météo.

# %%
# À compléter

# Indices :
# - pd.read_csv(...)
# - pd.read_excel(...)

# %% [markdown]
# ### Exercice 2
# À partir du DataFrame `df`, crée une variable `climat_df` et affiche les 4 premières lignes.

# %%
# À compléter

# Indices :
# - une simple affectation suffit
# - afficher les premières lignes avec .head(...)

# %% [markdown]
# ## 2. Visualiser rapidement les données
#
# ### Exercice 3
# Affiche :
# - les 5 premières lignes de `df`
# - les 2 dernières lignes de `df`
# - la taille du DataFrame

# %%
# À compléter

# Indices :
# - .head(...)
# - .tail(...)
# - .shape

# %% [markdown]
# ### Exercice 4
# Affiche :
# - les noms de colonnes
# - le type de chaque colonne
# - un résumé statistique des colonnes numériques

# %%
# À compléter

# Indices :
# - .columns
# - .dtypes
# - .describe()

# %% [markdown]
# ### Exercice 5
# Affiche les informations générales du DataFrame avec une seule commande.

# %%
# À compléter

# Indices :
# - utiliser .info()

# %% [markdown]
# ## 3. Sélection et filtrage
#
# ### Exercice 6
# Affiche uniquement la colonne `tavg`.
# Puis affiche uniquement les colonnes `ville`, `mois` et `tavg`.

# %%
# À compléter

# Indices :
# - une colonne : df["tavg"]
# - plusieurs colonnes : df[[..., ...]]

# %% [markdown]
# ### Exercice 7
# Filtre les lignes où :
# - `ville` vaut `"Paris"`
# - et `tavg` est strictement supérieure à 8

# %%
# À compléter

# Indices :
# - créer deux conditions
# - les combiner avec &
# - penser aux parenthèses

# %% [markdown]
# ### Exercice 8
# Filtre les lignes où la ville est `Paris` ou `Marseille`.

# %%
# À compléter

# Indices :
# - utiliser .isin(...)

# %% [markdown]
# ### Exercice 9
# Crée une nouvelle colonne `pluie_par_vent` égale à `precip_mm / wind_kmh`.
# Puis affiche `ville`, `mois`, `precip_mm`, `wind_kmh`, `pluie_par_vent`.

# %%
# À compléter

# Indices :
# - créer une colonne avec df["nouvelle_colonne"] = ...

# %% [markdown]
# ## 4. Données temporelles et index
#
# ### Exercice 10
# Convertis la colonne `mois` au format datetime, puis affiche son type.

# %%
# À compléter

# Indices :
# - utiliser pd.to_datetime(...)
# - vérifier avec df["mois"].dtype

# %%
# Vérification simple
assert str(df["mois"].dtype).startswith("datetime64")
print("Exercice 10 OK")

# %% [markdown]
# ### Exercice 11
# Crée un nouveau DataFrame `df_index` où `mois` devient l’index.
# Puis affiche les 4 premières lignes.

# %%
# À compléter

# Indices :
# - utiliser .set_index(...)

# %% [markdown]
# ### Exercice 12
# À partir de `df_index`, sélectionne uniquement les lignes de mars 2024.

# %%
# À compléter

# Indices :
# - si l'index est datetime, on peut utiliser .loc["2024-03"]

# %% [markdown]
# ## 5. Catégoriser des données
#
# ### Exercice 13
# Crée une nouvelle colonne `niveau_chaleur` :
# - `"froid"` si `tavg < 8`
# - `"tempere"` si `8 <= tavg < 12`
# - `"chaud"` sinon

# %%
# À compléter

# Indices :
# - utiliser np.select(...)
# - ou plusieurs affectations avec .loc

# %% [markdown]
# ### Exercice 14
# Transforme la colonne `zone_climatique` en type `category`, puis affiche son type.

# %%
# À compléter

# Indices :
# - utiliser .astype("category")

# %% [markdown]
# ## 6. Regroupements et sous-groupes
#
# ### Exercice 15
# Calcule la température moyenne par ville.

# %%
# À compléter

# Indices :
# - utiliser .groupby(...)
# - puis .mean()

# %% [markdown]
# ### Exercice 16
# Calcule, pour chaque ville :
# - la température moyenne
# - les précipitations totales

# %%
# À compléter

# Indices :
# - utiliser .agg(...)
# - penser à grouper par ville

# %% [markdown]
# ### Exercice 17
# Calcule la température moyenne par `ville` **et** par `zone_climatique`.

# %%
# À compléter

# Indices :
# - grouper sur une liste de colonnes

# %% [markdown]
# ## 7. Valeurs manquantes
#
# ### Exercice 18
# Affiche :
# - le nombre de valeurs manquantes par colonne
# - les lignes contenant au moins une valeur manquante

# %%
# À compléter

# Indices :
# - .isna().sum()
# - .isna().any(axis=1)

# %% [markdown]
# ### Exercice 19
# Crée un DataFrame `df_fill` dans lequel les valeurs manquantes de `precip_mm` sont remplacées par `0`.

# %%
# À compléter

# Indices :
# - utiliser .fillna(...)
# - pour éviter de modifier df directement, créer une copie

# %% [markdown]
# ### Exercice 20
# Crée un DataFrame `df_drop` sans les lignes où `precip_mm` est manquante.

# %%
# À compléter

# Indices :
# - utiliser .dropna(...)
# - cibler seulement la colonne precip_mm

# %% [markdown]
# ## 8. Jointures de DataFrames
#
# On crée ici deux petits DataFrames supplémentaires pour relier les observations météo à des métadonnées de station.

# %%
stations = pd.DataFrame({
    "station": ["PAR", "LYO", "MRS"],
    "latitude": [48.8566, 45.7640, 43.2965],
    "longitude": [2.3522, 4.8357, 5.3698],
    "altitude_m": [35, 173, 12]
})

zones = pd.DataFrame({
    "zone_climatique": ["nord", "interieur", "sud"],
    "description_zone": ["Influence oceanique", "Influence continentale", "Influence mediterraneenne"]
})

stations, zones

# %% [markdown]
# ### Exercice 21
# Fais une jointure interne (`inner`) entre `df` et `stations` sur `station`.

# %%
# À compléter

# Indices :
# - utiliser pd.merge(...)
# - préciser on="station"
# - how="inner"

# %% [markdown]
# ### Exercice 22
# Fais une jointure gauche (`left`) entre `df` et `zones` sur `zone_climatique`.

# %%
# À compléter

# Indices :
# - utiliser how="left"

# %% [markdown]
# ## 9. Reshape et pivot
#
# ### Exercice 23
# Crée un tableau croisé donnant la température moyenne (`tavg`) par `mois` et par `ville`.

# %%
# À compléter

# Indices :
# - utiliser .pivot_table(...)
# - index = mois, columns = ville, values = tavg

# %% [markdown]
# ### Exercice 24
# Transforme ce DataFrame :
#
# ```python
# large = pd.DataFrame({
#     "mois": ["2024-01", "2024-02"],
#     "Paris": [6.1, 7.8],
#     "Lyon": [4.8, 6.9]
# })
# ```
#
# en format long avec deux colonnes :
# - `ville`
# - `temperature`

# %%
# À compléter

# Indices :
# - créer d'abord le DataFrame large
# - utiliser pd.melt(...)

# %% [markdown]
# ## 10. Divers
#
# ### Exercice 25
# Trie `df` par `tavg` décroissantes, puis affiche les 5 premières lignes.

# %%
# À compléter

# Indices :
# - utiliser .sort_values(...)
# - ascending=False

# %% [markdown]
# ### Exercice 26
# Supprime les doublons éventuels sur les colonnes `ville` et `mois`.

# %%
# À compléter

# Indices :
# - utiliser .drop_duplicates(...)
# - subset=[...]

# %% [markdown]
# ### Exercice 27
# Renomme la colonne `tavg` en `temperature_moyenne` dans une copie du DataFrame.

# %%
# À compléter

# Indices :
# - utiliser .rename(columns={...})

# %% [markdown]
# ## 11. Performances
#
# ### Exercice 28
# Crée une colonne `alerte_chaleur` égale à :
# - `1` si `tavg >= 12`
# - `0` sinon
#
# Fais-le de façon vectorisée, sans boucle Python.
# <div style="border-left: 5px solid #20c997; background-color: #d1f7ec; padding: 10px; border-radius: 5px;">
# <b>💡 Documentation</b><br>
# https://numpy.org/doc/stable/reference/generated/numpy.where.html
# </div>

# %%
# À compléter

# Indices :
# - utiliser np.where(...)
# - éviter for ligne par ligne

# %% [markdown]
# ### Exercice 29
# Crée une colonne `indice_humide` égale à `humidite / 100 * precip_mm` de manière vectorisée.

# %%
# À compléter

# Indices :
# - une opération directe entre deux colonnes suffit

# %% [markdown]
# ## 12. Mini défi final
#
# À partir de `df`, construis un tableau de synthèse qui donne, pour chaque ville :
#
# 1. la température moyenne
# 2. les précipitations totales
# 3. la vitesse de vent moyenne
# 4. uniquement pour les lignes où `precip_mm` n’est pas manquante
#
# Trie le résultat par température moyenne décroissante.

# %%
# À compléter

# Indices :
# - commencer par filtrer les lignes sans NaN sur precip_mm
# - grouper par ville
# - utiliser .agg(...)
# - trier avec .sort_values(...)

# %% [markdown]
# # 📝 Corrections
#
# <div style="border-left: 5px solid #ffc107; background-color: #fff3cd; padding: 10px; border-radius: 5px;">
# Essaie d’abord de faire les exercices sans regarder cette partie.
# </div>

# %% [markdown]
# ## Correction 1

# %%
df_csv = pd.read_csv("meteo_mensuelle.csv")
df_xlsx = pd.read_excel("meteo_mensuelle.xlsx")

# %% [markdown]
# ## Correction 2

# %%
climat_df = df
climat_df.head(4)

# %% [markdown]
# ## Correction 3

# %%
df.head()
df.tail(2)
df.shape

# %% [markdown]
# ## Correction 4

# %%
df.columns
df.dtypes
df.describe()

# %% [markdown]
# ## Correction 5

# %%
df.info()

# %% [markdown]
# ## Correction 6

# %%
df["tavg"]
df[["ville", "mois", "tavg"]]

# %% [markdown]
# ## Correction 7

# %%
df[(df["ville"] == "Paris") & (df["tavg"] > 8)]

# %% [markdown]
# ## Correction 8

# %%
df[df["ville"].isin(["Paris", "Marseille"])]

# %% [markdown]
# ## Correction 9

# %%
df["pluie_par_vent"] = df["precip_mm"] / df["wind_kmh"]
df[["ville", "mois", "precip_mm", "wind_kmh", "pluie_par_vent"]]

# %% [markdown]
# ## Correction 10

# %%
df["mois"] = pd.to_datetime(df["mois"])
print(df["mois"].dtype)

# %% [markdown]
# ## Correction 11

# %%
df_index = df.set_index("mois")
df_index.head(4)

# %% [markdown]
# ## Correction 12

# %%
df_index.loc["2024-03"]

# %% [markdown]
# ## Correction 13

# %%
conditions = [
    df["tavg"] < 8,
    (df["tavg"] >= 8) & (df["tavg"] < 12),
    df["tavg"] >= 12
]
choix = ["froid", "tempere", "chaud"]

df["niveau_chaleur"] = np.select(conditions, choix)
df[["tavg", "niveau_chaleur"]]

# %% [markdown]
# ## Correction 14

# %%
df["zone_climatique"] = df["zone_climatique"].astype("category")
print(df["zone_climatique"].dtype)

# %% [markdown]
# ## Correction 15

# %%
df.groupby("ville")["tavg"].mean()

# %% [markdown]
# ## Correction 16

# %%
df.groupby("ville").agg({
    "tavg": "mean",
    "precip_mm": "sum"
})

# %% [markdown]
# ## Correction 17

# %%
df.groupby(["ville", "zone_climatique"])["tavg"].mean()

# %% [markdown]
# ## Correction 18

# %%
df.isna().sum()
df[df.isna().any(axis=1)]

# %% [markdown]
# ## Correction 19

# %%
df_fill = df.copy()
df_fill["precip_mm"] = df_fill["precip_mm"].fillna(0)
df_fill

# %% [markdown]
# ## Correction 20

# %%
df_drop = df.dropna(subset=["precip_mm"])
df_drop

# %% [markdown]
# ## Correction 21

# %%
pd.merge(df, stations, on="station", how="inner")

# %% [markdown]
# ## Correction 22

# %%
pd.merge(df, zones, on="zone_climatique", how="left")

# %% [markdown]
# ## Correction 23

# %%
df.pivot_table(index="mois", columns="ville", values="tavg", aggfunc="mean")

# %% [markdown]
# ## Correction 24

# %%
large = pd.DataFrame({
    "mois": ["2024-01", "2024-02"],
    "Paris": [6.1, 7.8],
    "Lyon": [4.8, 6.9]
})

pd.melt(large, id_vars="mois", var_name="ville", value_name="temperature")

# %% [markdown]
# ## Correction 25

# %%
df.sort_values("tavg", ascending=False).head()

# %% [markdown]
# ## Correction 26

# %%
df.drop_duplicates(subset=["ville", "mois"])

# %% [markdown]
# ## Correction 27

# %%
df_rename = df.rename(columns={"tavg": "temperature_moyenne"})
df_rename.head()

# %% [markdown]
# ## Correction 28

# %%
df["alerte_chaleur"] = np.where(df["tavg"] >= 12, 1, 0)
df[["tavg", "alerte_chaleur"]]

# %% [markdown]
# ## Correction 29

# %%
df["indice_humide"] = df["humidite"] / 100 * df["precip_mm"]
df[["humidite", "precip_mm", "indice_humide"]]

# %% [markdown]
# ## Correction du mini défi

# %%
df_valid = df.dropna(subset=["precip_mm"])

synthese = (
    df_valid
    .groupby("ville")
    .agg(
        temperature_moyenne=("tavg", "mean"),
        precipitations_totales=("precip_mm", "sum"),
        vent_moyen=("wind_kmh", "mean")
    )
    .sort_values("temperature_moyenne", ascending=False)
)

synthese

# %% [markdown]
# ## Suite
#
# Quand tu es à l’aise avec ce notebook, passe au suivant :
#
# - `04_visualisation.ipynb`
#
# Tu peux aussi revenir au cours complet :
# https://matbog.gitbook.io/python
