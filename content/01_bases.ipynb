# %% [markdown]
# # 01 — Bases de Python ⚙️
#
# Ce premier notebook est lié au [premier chapitre](https://matbog.gitbook.io/python/bases) du site Learn Python.
#
# On y traite les points suivants :
# - [Bases](https://matbog.gitbook.io/python/bases/bases),
# - [Types](https://matbog.gitbook.io/python/bases/les-types-en-python)
# - [Strings](https://matbog.gitbook.io/python/bases/les-chaines-de-caracteres-strings)
# - [Listes](https://matbog.gitbook.io/python/bases/les-listes)
# - [Dictionnaires](https://matbog.gitbook.io/python/bases/les-dictionnaires)
# - [Tuples et sets](https://matbog.gitbook.io/python/bases/tuples-et-set)
# - [Conditions](https://matbog.gitbook.io/python/bases/conditions-et-operateurs-logiques)
# - [Boucles](https://matbog.gitbook.io/python/bases/les-boucles)
# - [Fonctions](https://matbog.gitbook.io/python/bases/les-fonctions)
# - [Exceptions](https://matbog.gitbook.io/python/bases/exceptions)
# - [Inputs Utilisateurs](https://matbog.gitbook.io/python/bases/input-utilisateurs)
#
# <div style="border-left: 5px solid #20c997; background-color: #d1f7ec; padding: 10px; border-radius: 5px;">
# <b>💡 Rappel :</b><br>
#     <ul>
#         <li>Exécute les cellules avec <b>Shift + Enter</b></li>
#         <li>Écris ton code dans les cellules marquées <b># À compléter</b></li>
#         <li>Tu peux modifier les cellules autant de fois que nécessaire</li>
#         <li>Certaines cellules contiennent une <b>vérification simple</b></li>
#     </ul>
# </div>

# %% [markdown]
# ## 0. Échauffement
#
# Exécute la cellule ci-dessous pour vérifier que tout fonctionne.

# %%
print("Le notebook 01 climat est prêt 🚀")

# %% [markdown]
# ## 1. Variables et types
#
# ### Exercice 1
# Crée 4 variables :
# - `ville` contenant une chaîne de caractères
# - `temperature` contenant un nombre décimal
# - `jour` contenant un entier
# - `pluie` contenant un booléen
#
# Puis affiche les 4 variables.

# %%
# À compléter

# Indices :
# - une chaîne s'écrit entre guillemets
# - un float : 12.5
# - un entier : 3
# - un booléen : True ou False

# %%
# Vérification simple
assert isinstance(ville, str)
assert isinstance(temperature, float)
assert isinstance(jour, int)
assert isinstance(pluie, bool)
print("Exercice 1 OK")

# %% [markdown]
# ### Exercice 2
# Crée une variable `humidite = 78` puis affiche :
# - sa valeur
# - son type

# %%
# À compléter

# Indices :
# - utilise print(...)
# - le type s'obtient avec type(humidite)

# %% [markdown]
# ## 2. Chaînes de caractères
#
# ### Exercice 3
# Crée une variable `station = "Paris-Montsouris"` puis affiche :
# - le premier caractère
# - le dernier caractère
# - la longueur de la chaîne

# %%
# À compléter

# Indices :
# - premier caractère : index 0
# - dernier caractère : index -1
# - longueur : len(...)

# %% [markdown]
# ### Exercice 4
# Crée une variable `ville` puis fabrique un message du type :
#
# `La température à Lyon est agréable`
#
# Fais-le une première fois avec la concaténation, puis une seconde fois avec une `f-string`.

# %%
# À compléter

# Indices :
# - concaténation : "..." + ville + "..."
# - f-string : f"...{ville}..."

# %% [markdown]
# ### Exercice 5
# Crée une variable `phrase = "temperature moyenne mensuelle"` puis affiche :
# - la phrase en majuscules
# - la phrase avec `temperature` remplacé par `Température`
# - le nombre de fois où la lettre `e` apparaît

# %%
# À compléter

# Indices :
# - majuscules : .upper()
# - remplacement : .replace(...)
# - comptage : .count(...)

# %% [markdown]
# ## 3. Listes
#
# ### Exercice 6
# Crée une liste `temperatures = [6.2, 7.5, 10.1, 13.4, 16.8]` puis affiche :
# - la première température
# - la dernière température
# - la moyenne de la liste

# %%
# À compléter

# Indices :
# - premier élément : index 0
# - dernier élément : index -1
# - moyenne : somme / nombre d'éléments

# %% [markdown]
# ### Exercice 7
# À partir de la liste `villes = ["Paris", "Lyon", "Lille"]` :
# - ajoute `"Marseille"`
# - remplace `"Lyon"` par `"Bordeaux"`
# - affiche la liste finale

# %%
# À compléter

# Indices :
# - ajout : .append(...)
# - remplacement : modifier un élément par son index

# %% [markdown]
# ### Exercice 8
# Parcours la liste `precipitations = [12, 55, 8, 34, 72]` et affiche uniquement les valeurs supérieures à 30.

# %%
# À compléter

# Indices :
# - utiliser une boucle for
# - tester avec if

# %% [markdown]
# ## 4. Dictionnaires
#
# ### Exercice 9
# Crée un dictionnaire `station` avec les clés :
# - `nom`
# - `ville`
# - `altitude`
#
# Puis affiche :
# - le dictionnaire complet
# - la valeur associée à `altitude`

# %%
# À compléter

# Indices :
# - un dictionnaire s'écrit avec des accolades {}
# - accès à une clé : station["altitude"]

# %% [markdown]
# ### Exercice 10
# Ajoute une clé `latitude` au dictionnaire `station`, puis modifie l'altitude et affiche le résultat.

# %%
# À compléter

# Indices :
# - ajout/modification : station["latitude"] = ...

# %% [markdown]
# ## 5. Tuples et sets
#
# ### Exercice 11
# Crée un tuple `coordonnees = (48.85, 2.35)` puis affiche :
# - le tuple
# - la latitude
# - la longitude

# %%
# À compléter

# Indices :
# - un tuple utilise des parenthèses ()
# - accès comme une liste avec les index

# %% [markdown]
# ### Exercice 12
# Crée une liste `codes_stations = ["PAR", "LYO", "PAR", "MRS", "LYO"]`, transforme-la en `set`, puis affiche :
# - l'ensemble obtenu
# - le nombre de codes uniques

# %%
# À compléter

# Indices :
# - conversion en set : set(...)
# - nombre d'éléments : len(...)

# %% [markdown]
# ## 6. Conditions et opérateurs logiques
#
# ### Exercice 13
# Crée une variable `tmax`.
# Affiche :
# - `"Frais"` si la température est inférieure à 10
# - `"Doux"` si elle est entre 10 et 25 inclus
# - `"Chaud"` sinon

# %%
# À compléter

# Indices :
# - utiliser if / elif / else

# %% [markdown]
# ### Exercice 14
# Crée deux variables :
# - `vent = 22`
# - `pluie = True`
#
# Affiche `True` si :
# - le vent est supérieur à 20
# - et s'il pleut
#
# Sinon affiche `False`.

# %%
# À compléter

# Indices :
# - opérateur logique : and

# %% [markdown]
# ## 7. Boucles
#
# ### Exercice 15
# Affiche les mois de 1 à 12 avec une boucle `for`.

# %%
# À compléter

# Indices :
# - utiliser range(1, 13)

# %% [markdown]
# ### Exercice 16
# Calcule la somme des précipitations dans `liste = [12, 25, 8, 30]` avec une boucle.

# %%
# À compléter

# Indices :
# - créer une variable total = 0
# - ajouter chaque élément dans la boucle

# %% [markdown]
# ### Exercice 17
# Avec une boucle `while`, affiche les températures de 5 à 1.

# %%
# À compléter

# Indices :
# - commencer à 5
# - diminuer de 1 à chaque tour

# %% [markdown]
# ## 8. Fonctions
#
# ### Exercice 18
# Définis une fonction `fahrenheit(celsius)` qui retourne la température en Fahrenheit, puis teste-la avec 0 et 20.

# %%
# À compléter

# Indices :
# - formule : celsius * 9 / 5 + 32
# - utiliser return

# %%
# Vérification simple
assert fahrenheit(0) == 32
assert fahrenheit(20) == 68
print("Exercice 18 OK")

# %% [markdown]
# ### Exercice 19
# Définis une fonction `message_alerte(ville)` qui retourne :
# `Alerte météo pour <ville> !`

# %%
# À compléter

# Indices :
# - la fonction prend un argument ville
# - retourner une chaîne de caractères

# %% [markdown]
# ## 9. Exceptions
#
# ### Exercice 20
# Teste la division `100 / 0` dans un bloc `try / except` et affiche un message clair si une erreur se produit.

# %%
# À compléter

# Indices :
# - essayer dans un bloc try
# - intercepter ZeroDivisionError

# %% [markdown]
# ### Exercice 21
# Écris un code qui essaie de convertir la chaîne `"pluie"` en entier.
# Gère l'erreur proprement avec `try / except`.

# %%
# À compléter

# Indices :
# - conversion : int("pluie")
# - intercepter ValueError

# %% [markdown]
# ## 10. Input utilisateur
#
# ### Exercice 22
# Demande à l'utilisateur son nom de ville avec `input()` puis affiche un message météo.
#
# Si `input()` est peu pratique dans ton navigateur, tu peux tester aussi avec une variable :
# `ville = "Paris"`

# %%
# À compléter

# Indices :
# - interactive : input("Nom de la ville : ")
# - secours : ville = "Paris"
# - affichage : f"...{ville}..."

# %% [markdown]
# ### Exercice 23
# Demande deux températures à l'utilisateur, convertis-les en `float`, puis affiche leur moyenne.
#
# Là encore, tu peux remplacer temporairement `input()` par des variables si besoin.

# %%
# À compléter

# Indices :
# - float(input(...))
# - version de secours possible avec deux variables numériques

# %% [markdown]
# ## 11. Mini défi final
#
# Crée un petit programme qui :
#
# 1. stocke une liste de températures
# 2. calcule la moyenne
# 3. affiche `"Période chaude"` si la moyenne est au moins égale à 15
# 4. sinon affiche `"Période fraîche"`
#
# Essaie d'écrire la solution toi-même avant de regarder les corrections.

# %%
# À compléter

# Indices :
# - temperatures = [...]
# - moyenne = sum(temperatures) / len(temperatures)
# - utiliser if / else

# %% [markdown]
# # 📝 Corrections
#
# <div style="border-left: 5px solid #ffc107; background-color: #fff3cd; padding: 10px; border-radius: 5px;">
# Essaie d’abord de faire les exercices sans regarder cette partie.
# </div>

# %% [markdown]
# ## Correction 1

# %%
ville = "Paris"
temperature = 12.5
jour = 3
pluie = True

print(ville, temperature, jour, pluie)

# %% [markdown]
# ## Correction 2

# %%
humidite = 78
print(humidite)
print(type(humidite))

# %% [markdown]
# ## Correction 3

# %%
station = "Paris-Montsouris"
print(station[0])
print(station[-1])
print(len(station))

# %% [markdown]
# ## Correction 4

# %%
ville = "Lyon"

message1 = "La température à " + ville + " est agréable"
message2 = f"La température à {ville} est agréable"

print(message1)
print(message2)

# %% [markdown]
# ## Correction 5

# %%
phrase = "temperature moyenne mensuelle"
print(phrase.upper())
print(phrase.replace("temperature", "Température"))
print(phrase.count("e"))

# %% [markdown]
# ## Correction 6

# %%
temperatures = [6.2, 7.5, 10.1, 13.4, 16.8]
print(temperatures[0])
print(temperatures[-1])
print(sum(temperatures) / len(temperatures))

# %% [markdown]
# ## Correction 7

# %%
villes = ["Paris", "Lyon", "Lille"]
villes.append("Marseille")
villes[1] = "Bordeaux"
print(villes)

# %% [markdown]
# ## Correction 8

# %%
precipitations = [12, 55, 8, 34, 72]

for p in precipitations:
    if p > 30:
        print(p)

# %% [markdown]
# ## Correction 9

# %%
station = {
    "nom": "Montsouris",
    "ville": "Paris",
    "altitude": 75
}

print(station)
print(station["altitude"])

# %% [markdown]
# ## Correction 10

# %%
station["latitude"] = 48.82
station["altitude"] = 80
print(station)

# %% [markdown]
# ## Correction 11

# %%
coordonnees = (48.85, 2.35)
print(coordonnees)
print(coordonnees[0])
print(coordonnees[1])

# %% [markdown]
# ## Correction 12

# %%
codes_stations = ["PAR", "LYO", "PAR", "MRS", "LYO"]
uniques = set(codes_stations)

print(uniques)
print(len(uniques))

# %% [markdown]
# ## Correction 13

# %%
tmax = 18

if tmax < 10:
    print("Frais")
elif tmax <= 25:
    print("Doux")
else:
    print("Chaud")

# %% [markdown]
# ## Correction 14

# %%
vent = 22
pluie = True

print(vent > 20 and pluie)

# %% [markdown]
# ## Correction 15

# %%
for mois in range(1, 13):
    print(mois)

# %% [markdown]
# ## Correction 16

# %%
liste = [12, 25, 8, 30]
total = 0

for x in liste:
    total += x

print(total)

# %% [markdown]
# ## Correction 17

# %%
n = 5
while n >= 1:
    print(n)
    n -= 1

# %% [markdown]
# ## Correction 18

# %%
def fahrenheit(celsius):
    return celsius * 9 / 5 + 32

print(fahrenheit(0))
print(fahrenheit(20))

# %% [markdown]
# ## Correction 19

# %%
def message_alerte(ville):
    return f"Alerte météo pour {ville} !"

print(message_alerte("Paris"))

# %% [markdown]
# ## Correction 20

# %%
try:
    resultat = 100 / 0
    print(resultat)
except ZeroDivisionError:
    print("Erreur : division par zéro")

# %% [markdown]
# ## Correction 21

# %%
try:
    nombre = int("pluie")
    print(nombre)
except ValueError:
    print("Erreur : conversion impossible en entier")

# %% [markdown]
# ## Correction 22

# %%
# ville = input("Nom de la ville : ")
ville = "Paris"

print(f"Prévision météo simplifiée pour {ville}")

# %% [markdown]
# ## Correction 23

# %%
# t1 = float(input("Température 1 : "))
# t2 = float(input("Température 2 : "))

t1 = 12.5
t2 = 18.0

print("Moyenne =", (t1 + t2) / 2)

# %% [markdown]
# ## Correction du mini défi

# %%
temperatures = [8.5, 11.2, 15.0, 17.8]
moyenne = sum(temperatures) / len(temperatures)

print("Moyenne :", moyenne)

if moyenne >= 15:
    print("Période chaude")
else:
    print("Période fraîche")

# %% [markdown]
# ## Suite
#
# Quand tu es à l’aise avec ce notebook, passe au suivant :
#
# - `02_numpy.ipynb`
#
# Tu peux aussi revenir au cours complet :
# https://matbog.gitbook.io/python
