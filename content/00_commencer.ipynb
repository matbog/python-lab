# %% [markdown]
# # 🚀 Bienvenue dans le Python Lab
#
# Ce laboratoire te permet de pratiquer Python directement dans ton navigateur.
#
# 👉 Cours complet :
# https://matbog.gitbook.io/python
#
# ---
#
# ## 🎯 Objectif
#
# - Comprendre les bases
# - Tester du code immédiatement
# - Apprendre en pratiquant
#
# ---
#
# 👉 Commence ensuite avec :
#
# - `01_bases.ipynb`
# - `02_numpy.ipynb`
# - `03_pandas.ipynb`
# - `04_visualisation.ipynb`

# %% [markdown]
# # ⚡ Comment utiliser ce notebook
#
# ## ▶️ Exécuter du code
#
# 1. Clique dans une cellule
# 2. Appuie sur **Shift + Enter**
#
# 👉 Essaie ci-dessous :

# %%
print("Hello 👋")

# %% [markdown]
# ## ✏️ Modifier le code
#
# Tu peux modifier n'importe quelle cellule.
#
# 👉 Exemple :

# %%
print("Modifie ce texte puis exécute la cellule")

# %% [markdown]
# ## ➕ Ajouter une cellule
#
# - Bouton "+"
# - Ou clic droit → Insert Cell
#
# ---
#
# ## ❌ En cas d'erreur
#
# Lis le message affiché sous la cellule.
#
# 👉 Exemple :

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 👉 Ici, `x` n'existe pas → erreur normale
#
# ---
#
# # 🧪 Comment faire les exercices
#
# 1. Lis l'énoncé
# 2. Écris ton code
# 3. Exécute la cellule
# 4. Corrige si besoin
#
# ---
#
# # ⚠️ Important
#
# - Ton travail est sauvegardé **dans ton navigateur uniquement**
# - Si tu changes d'ordinateur ou vides le cache → tu perds tout
#
# ---
#
# # 🚫 À éviter
#
# - Ne crée pas de nouveaux notebooks
# - Travaille directement dans ceux fournis
#
# ---
#
# # 📘 Suite
#
# 👉 Passe maintenant à :
#
# - `01_bases.ipynb`
