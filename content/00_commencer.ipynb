# %% [markdown]
# # 🚀 Bienvenue dans le Python Lab
#
# Ce laboratoire te permet de pratiquer Python directement dans ton navigateur.
#
# 👉 Cours complet :
# https://matbog.gitbook.io/python
#
# ---
#
# # ⚡ Comment utiliser ce notebook
#
# ## ▶️ Exécuter du code
#
# - Clique dans une cellule
# - Appuie sur **Shift + Enter**
#
# ---
#
# ## ✏️ Modifier le code
#
# Tu peux modifier n'importe quelle cellule, puis l'executer, toujours avec **Shift + Enter** : essai ci-dessous ↓

# %%
print("Modifie-moi !")
# Out:
# Modifie-moi !
