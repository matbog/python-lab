# %% [markdown]
# # 🚀 Bienvenue dans le Python Lab
#
# Ce laboratoire permet de pratiquer Python directement dans son navigateur.
#
# Il est en lien avec un cours complet, disponible ici :
# https://matbog.gitbook.io/python
#
# ---
#
# ## 🎯 Objectif
#
# - Comprendre les bases, puis des éléments plus avancés
# - Tester du code immédiatement
# - Apprendre en pratiquant
#
#
# 🎓 Il y a 4 notebook qui suivent, qui coorespondent aux grand chapitre des cours.
#
# - Les [bases](https://matbog.gitbook.io/python/bases) : `01_bases.ipynb`
# - [Numpy](https://matbog.gitbook.io/python/numpy) : `02_numpy.ipynb`
# - [Pandas](https://matbog.gitbook.io/python/pandas) : `03_pandas.ipynb`
# - [La visualisation](https://matbog.gitbook.io/python/visualisation) : `04_visualisation.ipynb`
#
# ---
#
# # Comment utiliser ce notebook
#
# ## ⚙️ Exécuter du code
#
# 1. Clique dans une cellule
# 2. Appuie sur **Shift + Enter**
#
# ▶️ Essaie ci-dessous :

# %%
print("Hello World")

# %% [markdown]
# ## ✏️ Modifier le code
#
# Tu peux modifier n'importe quelle cellule.
#
# ▶️ Exemple :

# %%
print("Modifie ce texte puis exécute la cellule")

# %% [markdown]
# ## ➕ Ajouter une cellule
#
# - Bouton "+" à droite
#
# ## ❌ En cas d'erreur
#
# Lis le message affiché sous la cellule.
#
# ▶️ Exemple :

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ▶️ Ici, `x` n'existe pas → erreur normale
#
# ---
#
# # ✅ Ce que tu peux faire
#
# - Exécuter du code Python directement dans ton navigateur
# - Modifier les cellules existantes
# - Tester tes propres idées
# - Revenir en arrière et réexécuter les cellules
# - Explorer librement le code proposé
#
# ▶️ N’hésite pas à expérimenter !
#
# # ⚠️ Ce que tu ne peux pas faire
#
# - Installer n'importe quelle bibliothèque Python (seules certaines sont disponibles)
# - Sauvegarder ton travail en ligne
# - Partager ton notebook avec d'autres utilisateurs
# - Faire des calculs très lourds (tout tourne dans ton navigateur)
#
# ▶️ Ce labo est fait pour apprendre, pas pour faire des projets lourds.
#
# ---
# # 💡 Bonnes pratiques
#
# - Lis bien les consignes avant de coder
# - Exécute les cellules dans l'ordre
# - Si quelque chose ne marche pas, relance le notebook (Kernel → Restart)
# - Teste plusieurs solutions
#
# ▶️ L’erreur fait partie de l’apprentissage
#
#
# ---
#
# # ⚠️ Important
#
# - Ton travail est sauvegardé **dans ton navigateur uniquement**
# - Si tu changes d'ordinateur ou vides le cache → tu perds tout
#
# ---
#
# # 🚫 À éviter
#
# - Ne crée pas de nouveaux notebooks
# - Travaille directement dans ceux fournis
#
# ---
#
# # 🛠️ En cas de problème
#
# ### Rien ne marche ?
# - Recharge la page
#
# ### Résultat étrange ?
# - Relance toutes les cellules (Restart Kernel + Run All)
#
# ### Tu es bloqué ?
# - Reviens au cours GitBook :
# https://matbog.gitbook.io/python
#
# ---
#
# 👉 Astuce : si tout est cassé, recharge la page pour repartir de zéro
# ---
#
# _Bonne exploration !_
